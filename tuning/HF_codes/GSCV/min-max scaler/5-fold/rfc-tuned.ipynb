# %%
import warnings
warnings.filterwarnings("ignore")
import time
to=time.clock()
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler 
scale=MinMaxScaler()
heart="../input/heart-failure/heart_failure.csv"
data=pd.read_csv (heart)
x=data.drop('DEATH_EVENT',axis=1)
x=scale.fit_transform(x)
y=data['DEATH_EVENT']

grid={
    'n_estimators':[10,50,100],
    'min_samples_split':[1,2,5],
    'min_samples_leaf':[1,2,5],
    'max_features':['auto'],
    'bootstrap':[True,False],
    'max_depth':[2,4,None]
}
model=RandomForestClassifier()
rdm = GridSearchCV(model,grid,cv=5)
rdm.fit(x,y)
print("RFC accuracy:",rdm.best_score_)
print("RFC best params:",rdm.best_params_)
t1=time.clock()
print(t1-to)
# Out:
# RFC accuracy: 0.7489265536723164
# RFC best params: {'bootstrap': False, 'max_depth': 4, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 10}
# 58.566966
