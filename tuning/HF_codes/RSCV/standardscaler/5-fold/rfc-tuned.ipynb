# %%
import warnings
warnings.filterwarnings("ignore")
import time
to=time.clock()
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler 
scale=StandardScaler()
heart="../input/heart-failure/heart_failure.csv"
data=pd.read_csv (heart)
x=data.drop('DEATH_EVENT',axis=1)
x=scale.fit_transform(x)
y=data['DEATH_EVENT']

grid={
    'n_estimators':[10,50,100],
    'min_samples_split':[1,2,5],
    'min_samples_leaf':[1,2,5],
    'max_features':['auto'],
    'bootstrap':[True,False],
    'max_depth':[2,4,None]
}
model=RandomForestClassifier()
rdm = RandomizedSearchCV(model,param_distributions=grid)
rdm.fit(x,y)
print("RFC accuracy:",rdm.best_score_)
print("RFC best params:",rdm.best_params_)
t1=time.clock()
print(t1-to)
# Out:
# RFC accuracy: 0.7690395480225989
# RFC best params: {'n_estimators': 50, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 2, 'bootstrap': False}
# 4.006119999999996
