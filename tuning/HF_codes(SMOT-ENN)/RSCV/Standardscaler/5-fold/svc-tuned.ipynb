# %%
import warnings
warnings.filterwarnings("ignore")
import time
to=time.clock()
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import accuracy_score
from statistics import stdev
from sklearn.preprocessing import StandardScaler 
scale=StandardScaler()
heart="../input/heart-failure/heart_failure.csv"
df = pd.read_csv(heart)
x = df.drop(columns=['DEATH_EVENT'])
x=scale.fit_transform(x)
y = df['DEATH_EVENT']
from imblearn.combine import SMOTEENN
ada = SMOTEENN()
x, y= ada.fit_resample(x, y)
model=SVC()
grid={
    'C': [0.001,0.01,0.1,1,10,100],
    'kernel': ['rbf'],
    'gamma': ['auto','scale',0.001,0.1,1,10],
    'probability':[True]
}
rdm = RandomizedSearchCV(model,grid,cv=5)
rdm.fit(x,y)
print("best score:",rdm.best_score_)
print("best parameters:",rdm.best_params_)
t1=time.clock()
print(t1-to)
# Out:
# best score: 0.9829787234042552
# best parameters: {'probability': True, 'kernel': 'rbf', 'gamma': 0.001, 'C': 100}
# 0.6056660000000029
